# %% [markdown]
# <a href="https://colab.research.google.com/github/Bonface-3020/data-visualization/blob/main/Line_graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x=[0,5,10,15,20,25,30]
y1=[10,15,20,20,30,15,0]
y2=[10,12,21,30,20,12,0]
plt.plot(x,y1,linestyle='dashed',marker='D')
plt.plot(x,y2,linestyle='dashed',marker='D')
plt.title('Velocity-Time Graph')
plt.xlabel('Time(s)')
plt.ylabel('Velocity(m/s)')
plt.xlim(5,50)
plt.ylim(5,50)
plt.grid(True)
plt.legend()
plt.show()
# Out:
# /tmp/ipython-input-6-168272170.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
