# %% [markdown]
# <a href="https://colab.research.google.com/github/Bonface-3020/data-visualization/blob/main/Histogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
blood_sugar_men=[113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]
type=[blood_sugar_men,blood_sugar_women]
color=['g','r']
label=['men','women']
bins=[80,100,125,150]
plt.xlabel("Blood Sugar Range")
plt.ylabel("Total no. of patients")

plt.hist(type,bins=bins,rwidth=0.95,color=color,label=label,orientation='horizontal')
plt.title("Histogram of Blood Sugar Range")
plt.legend()
plt.show()

# %%
student_marks=[23,34,12,56,75,89,60,32,41,32,56,78,90,99]
type=['student_marks']
bins=[0,20,40,60,80,100]
